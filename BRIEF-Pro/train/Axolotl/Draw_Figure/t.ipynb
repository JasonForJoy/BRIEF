# %%
# 8B

F1_Our = [53.96, 49.74, 49.54, 47.2, 46.53]
EM_Our = [43.2, 39.4, 38.8, 36.6, 35.8]

F1_Longllmlingua = [35.94, 22.47, 22.13, 21.49, 20.4]
EM_Longllmlingua = [23.6, 12.8, 12.0, 13.0, 12.2]

# %%
Avg_Our = [(f1 + em) / 2 for f1, em in zip(F1_Our, EM_Our)]

Avg_Longllmlingua = [(f1 + em) / 2 for f1, em in zip(F1_Longllmlingua, EM_Longllmlingua)]

print(Avg_Our)
print(Avg_Longllmlingua)
# Out:
# [48.58, 44.57, 44.17, 41.900000000000006, 41.165]
# [29.77, 17.634999999999998, 17.064999999999998, 17.244999999999997, 16.299999999999997]

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
x = [20, 40, 60, 80, 100]
y1 = Avg_Our      # 第一组
y2 = Avg_Longllmlingua     # 第二组

plt.figure(figsize=(4.5,4))

# 第一条线
plt.plot(x, y1, marker='^', color='brown', linewidth=2, markersize=8, label='BRIEF-PRO')
# 第二条线
plt.plot(x, y2, marker='D', color='gray', linewidth=2, markersize=8, label='LongLLMLingua')

# 图例
plt.legend()

# 坐标轴标签和标题
plt.xlabel('Number of Documents')
plt.ylabel('Score')
plt.title('Llama-3.1-8B-Instruct')

# 设置刻度和边框
plt.xticks(x)
plt.ylim(10, 55)

# 加上虚线背景网格
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)


plt.tight_layout()

plt.show()

# %%
# 70B

F1_Our = [68.31, 64.16, 62.66, 60.3, 59.41]
EM_Our = [56.2, 52.6, 51.2, 49.0, 47.6]

F1_Longllmlingua = [55.5, 40.04, 36.22, 34.23, 31.56]
EM_Longllmlingua = [43.2, 27.8, 25.4, 23.8, 20.6]

# %%
Avg_Our = [(f1 + em) / 2 for f1, em in zip(F1_Our, EM_Our)]

Avg_Longllmlingua = [(f1 + em) / 2 for f1, em in zip(F1_Longllmlingua, EM_Longllmlingua)]

print(Avg_Our)
print(Avg_Longllmlingua)
# Out:
# [62.255, 58.379999999999995, 56.93, 54.65, 53.504999999999995]
# [49.35, 33.92, 30.81, 29.015, 26.08]

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
x = [20, 40, 60, 80, 100]
y1 = Avg_Our      # 第一组
y2 = Avg_Longllmlingua     # 第二组

plt.figure(figsize=(4.5,4))

# 第一条线
plt.plot(x, y1, marker='^', color='brown', linewidth=2, markersize=8, label='BRIEF-PRO')
# 第二条线
plt.plot(x, y2, marker='D', color='gray', linewidth=2, markersize=8, label='LongLLMLingua')

# 图例
plt.legend()

# 坐标轴标签和标题
plt.xlabel('Number of Documents')
plt.ylabel('Score')
plt.title('Llama-3.1-70B-Instruct')

# 设置刻度和边框
plt.xticks(x)
plt.ylim(20, 70)

# 加上虚线背景网格
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)


plt.tight_layout()

plt.show()

# %%
# GPT4.1

F1_Our = [57.84, 54.4, 53.98, 50.65, 49.2]
EM_Our = [47.8, 45.6, 43.8, 41.4, 39.6]

F1_Longllmlingua = [36.27, 26.69, 26.55, 23.35, 21.95]
EM_Longllmlingua = [24.4, 16.8, 16.4, 14.8, 12.8]

# %%
Avg_Our = [(f1 + em) / 2 for f1, em in zip(F1_Our, EM_Our)]

Avg_Longllmlingua = [(f1 + em) / 2 for f1, em in zip(F1_Longllmlingua, EM_Longllmlingua)]

print(Avg_Our)
print(Avg_Longllmlingua)
# Out:
# [52.82, 50.0, 48.89, 46.025, 44.400000000000006]
# [30.335, 21.745, 21.475, 19.075000000000003, 17.375]

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
x = [20, 40, 60, 80, 100]
y1 = Avg_Our      # 第一组
y2 = Avg_Longllmlingua     # 第二组

plt.figure(figsize=(4.5,4))

# 第一条线
plt.plot(x, y1, marker='^', color='brown', linewidth=2, markersize=8, label='BRIEF-PRO')
# 第二条线
plt.plot(x, y2, marker='D', color='gray', linewidth=2, markersize=8, label='LongLLMLingua')

# 图例
plt.legend()

# 坐标轴标签和标题
plt.xlabel('Number of Documents')
plt.ylabel('Score')
plt.title('GPT4.1')

# 设置刻度和边框
plt.xticks(x)
plt.ylim(10, 65)

# 加上虚线背景网格
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)


plt.tight_layout()

plt.show()
